# %%
import os
from pathlib import Path
import pandas as pd

# %%
try:
  from qdrant_client import models, QdrantClient
except:
  # !pip install qdrant-client > /dev/null
  from qdrant_client import models, QdrantClient
try:
  from sentence_transformers import SentenceTransformer
except:
  # !pip install sentence_transformers > /dev/null
  from sentence_transformers import SentenceTransformer

# %%
# Hiding warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Helper functions

# %%
def search_metrics(client, encoder, metric, cat):
    category_result = []

    collection_name = f"citp_{metric}"

    hits = client.search(
        collection_name=collection_name,
        query_vector=encoder.encode(cat).tolist(),
        limit=3
    )
    for hit in hits:
        category_result.append({
            **hit.payload,
            "score": hit.score,
            "name": cat
        })

    result_df = pd.DataFrame(category_result)

    highest = rename_columns(highest_score(result_df), f"{metric}_highest")
    simple = rename_columns(simple_count(result_df), f"{metric}_simple")
    weighted = rename_columns(weighted_count(result_df), f"{metric}_weighted")

    long_df = pd.concat([highest, simple, weighted])

    return long_df


def rename_columns(df: pd.DataFrame, suffix:str) -> pd.DataFrame:
    """Function to add a suffix to specific columns
    """
    df = df.rename(columns={
        "code": f"code_{suffix}",
        "score": f"score_{suffix}",
        "count": f"score_{suffix}"})
    return df


def weighted_count(df: pd.DataFrame) -> pd.DataFrame:
    """Function to select the classification with the highest count
    of classification weighted by scores
    """
    grouped = df.groupby(['label', 'citp_code']).sum("score").reset_index()
    result = grouped.loc[grouped.groupby('label')['score'].idxmax()]
    return result


def simple_count(df: pd.DataFrame) -> pd.DataFrame:
    """Function to select the classification with the highest count
    of classification
    """
    counted = df.groupby(['label', 'citp_code']).size().reset_index(name='count')
    # Find the 'coicop_code' with the highest count for each 'name'
    result = counted.loc[counted.groupby('label')['count'].idxmax()]
    return result


def highest_score(df: pd.DataFrame) -> pd.DataFrame:
    """Function to select the classification with the highest score
    """
    # Find the index of the maximum score for each name
    idx = df.groupby('label')['score'].idxmax()

    # Select the rows corresponding to these indices
    result = df.loc[idx]
    return result


def majority_vote(df: pd.DataFrame) -> pd.DataFrame:
    counted = df.groupby(['label', 'citp_code']).size().reset_index(name='count')
    # Find the 'coicop_code' with the highest count for each 'name'
    result = counted.loc[counted.groupby('label')['count'].idxmax()]

    result["confidence"] = result["count"] / 6

    return result.to_dict(orient='records')[0]

# %% [markdown]
# ## Load data

# %%
home = Path('C:/Users/f.migone/Desktop/codif_rag_ene')

# %%
examples_df = pd.read_excel(home.joinpath("data_T4_2024_enem.xlsx"), dtype=str)
products_df = pd.read_excel(home.joinpath("file_manually_coded.xlsx"), dtype=str)

# %% [markdown]
# Renaming columns for convenience

# %%
examples_df.columns = ["label", "citp_code"]

# %%
products_df = products_df[["label", "code"]]
products_df.columns = ["label", "citp_code"]

# %%
products_df['citp_code'].unique()
# Out:
# array(['422005', '611001', '332003', '333202', '532002', '911002',
#        '541401', '721001', '331101', '333104', '342204', '613001',
#        '613098', '921001', '712002', '612005', '711006', '216299',
#        '532004', '931201', '522001', '962012', '941001', '521106',
#        '314199', '514001', '723001', '752001', '265202', '421004',
#        '321204', '321205', '322002', '611007', '961005', '516005',
#        '751202', '832103', '521101', '523001', '962013', '711004',
#        '833003', '832203', '832201', '832101', '833002', '314106',
#        '711001', '313099', '522003', '521102', '521104', '521199',
#        '521108', '521105', '962010', '521107', '323001', '524201',
#        '834002', '752006', '834001', '235102', '314102', '962099',
#        '933003', '753304', '753102', '512000', '611006', '933004',
#        '325199', '342205', '130005', '130099', '962004', '531002',
#        '431204', '235103', '741001', '612002', '612001', '911001',
#        '234001', '233005', '234003', '235299', '514003', '754099',
#        '812001', '112003', '342199', '722002', '712007', '311402',
#        '140005', '951002', '522002', '241099', '334001', '216205',
#        '611003', '611005', '322001', '222001', '216204', '252001',
#        '214001', '235101', '516007', '521103', '622102', '321203',
#        '912001', '962002', '432101', '814002', '323003', '931103',
#        '821099', '834099', '811102', '263305', '343007', '723006',
#        '713001', '732002', '343001', '622101', '524105', '421002',
#        '242006', '341299', '226001', '742002', '513003', '222002',
#        '752003', '721003', '711005', '422004', '312099', '333204',
#        '753202', '311201', '314110', '314301', '311303', '753104',
#        '961001', '751302', '524299', '226002', '411008', '411007',
#        '431102', '325104', '932002', '931204', '265499', '834004',
#        '331207', '331204', '912002', '751103', '632001', '732099',
#        '933099', '832202', '312008', '112001', '951003', '951099',
#        '335301', '112005', '422001', '752002', '311302', '613099',
#        '811201', '432201', '342102', '541203', '31007', '351003',
#        '912003', '511005', '513002', '251001', '251099', '264201',
#        '722004', '522006', '931101', '516003', '723099', '221001',
#        '816001', '751102', '541101', '731104', '343099', '411004',
#        '742004', '541102', '412000', '811101', '226011', '352002',
#        '314111', '333201', '961003'], dtype=object)

# %%
examples_df['citp_code'].unique()
# Out:
# array(['021004', '031006', '031007', '111206', '111403', '111405',
#        '111407', '111408', '112002', '112005', '120008', '130001',
#        '130008', '130012', '130099', '140002', '140004', '140005',
#        '213201', '213208', '214005', '214099', '215003', '216101',
#        '216103', '216203', '221001', '222001', '222002', '224099',
#        '225000', '226001', '226006', '226099', '231002', '232000',
#        '233003', '233004', '233005', '234001', '234002', '235101',
#        '235102', '235103', '235201', '235202', '235299', '235399',
#        '235402', '235499', '241001', '241003', '241099', '242005',
#        '242006', '242008', '243099', '252001', '263302', '263304',
#        '263305', '263307', '264203', '265101', '265201', '265202',
#        '311101', '311201', '311301', '311302', '311303', '311304',
#        '311499', '312004', '313001', '314101', '314102', '314104',
#        '314105', '314106', '314107', '314108', '314109', '314302',
#        '314304', '315104', '321102', '322001', '322002', '322003',
#        '323001', '323003', '323099', '325102', '325103', '325104',
#        '325110', '325199', '325299', '331204', '331206', '331207',
#        '332001', '332003', '332099', '333103', '333104', '333199',
#        '333201', '333202', '333204', '334002', '334003', '334005',
#        '335301', '341203', '342102', '342204', '343001', '343003',
#        '343007', '351003', '351004', '352001', '352002', '411004',
#        '411005', '411006', '411007', '411008', '413002', '421002',
#        '422005', '422006', '431101', '431102', '431103', '431201',
#        '431202', '431203', '432103', '432202', '512000', '513001',
#        '513002', '513003', '514001', '514003', '516003', '516005',
#        '516007', '516099', '521101', '521102', '521103', '521104',
#        '521105', '521106', '521107', '521108', '521199', '522001',
#        '522002', '522003', '522006', '523001', '524105', '524106',
#        '524201', '524299', '531002', '532003', '532004', '532005',
#        '532006', '532007', '532099', '541101', '541102', '541103',
#        '541201', '541203', '541401', '611001', '611002', '611003',
#        '611004', '611006', '611007', '612001', '612002', '612005',
#        '612099', '613001', '613098', '613099', '621099', '622101',
#        '622102', '622104', '631001', '631099', '711001', '711004',
#        '711006', '712001', '712002', '712006', '712007', '712008',
#        '712009', '713001', '721003', '721005', '722002', '722003',
#        '723001', '723003', '723004', '723005', '723099', '731103',
#        '731104', '731299', '741001', '741002', '742002', '742004',
#        '742099', '751102', '751103', '751201', '751202', '751301',
#        '751302', '752001', '752002', '752003', '753102', '753104',
#        '753105', '753202', '753304', '754099', '811102', '811104',
#        '811202', '811204', '812001', '812002', '815002', '815003',
#        '815006', '816001', '821002', '821099', '832101', '832104',
#        '832201', '832202', '832203', '833002', '833003', '834001',
#        '834004', '911001', '911002', '912001', '912002', '912003',
#        '912099', '921001', '921002', '921003', '921004', '931101',
#        '931103', '931201', '931202', '931205', '931299', '932099',
#        '933003', '933004', '933099', '941001', '951002', '951003',
#        '951099', '961001', '961003', '961005', '962002', '962003',
#        '962004', '962009', '962010', '962012', '962013'], dtype=object)

# %% [markdown]
# There are several products in the "ivory_cost_09032024_valide_code.xlsx" files which belongs to COICOP codes not present in the example file. Those products may not be classified correctly, because there is no example for the subclass they belong to. In order to get a reasonable idea of the accuracy of the proposed methodology, we remove those products (if we populate the database with all the already classified products, we should have examples for all subclassess).

# %%
products_df = products_df[products_df['citp_code'].isin(examples_df['citp_code'].unique())]

# %% [markdown]
# ## Qdrant database

# %% [markdown]
# Load data from products already classified in the Qdrant Database.

# %%
data_dict = examples_df.to_dict("records")

# %%
encoder = SentenceTransformer("paraphrase-multilingual-mpnet-base-v2")
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# c:\Users\f.migone\AppData\Local\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\f.migone\.cache\huggingface\hub\models--sentence-transformers--paraphrase-xlm-r-multilingual-v1. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.56k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/718 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/550 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
client = QdrantClient(":memory:")

# %% [markdown]
# ### Cosine distance

# %%
client.create_collection(
    collection_name="citp_cosine",
    vectors_config=models.VectorParams(
        size=encoder.get_sentence_embedding_dimension(),  # Vector size is defined by used model
        distance=models.Distance.COSINE,
    ),
)
# Out:
# True

# %%
client.upload_points(
    collection_name="citp_cosine",
    points=[
        models.PointStruct(
            id=idx, vector=encoder.encode(doc["label"]).tolist(), payload=doc
        )
        for idx, doc in enumerate(data_dict)
    ],
)

# %% [markdown]
# ### Dot product distance

# %%
client.create_collection(
    collection_name="citp_dot",
    vectors_config=models.VectorParams(
        size=encoder.get_sentence_embedding_dimension(),  # Vector size is defined by used model
        distance=models.Distance.DOT,
    ),
)
# Out:
# True

# %%
client.upload_points(
    collection_name="citp_dot",
    points=[
        models.PointStruct(
            id=idx, vector=encoder.encode(doc["label"]).tolist(), payload=doc
        )
        for idx, doc in enumerate(data_dict)
    ],
)

# %%
def predict(input_dict, client, encoder):
    """
    Prediction given the request input
    :param input_dict: [dict], product to be classfied
    :param client: [QdrantClient], Qdrant client
    :param encoder: [SentenceTransformer], SentenceTransformer model for embeddings
    :return: [dict], prediction
    """

    name = input_dict.get("label")


    results_cosine = search_metrics(client, encoder, "cosine", name)
    results_dot = search_metrics(client, encoder, "dot", name)

    results_concat = pd.concat([results_cosine, results_dot])

    result = majority_vote(results_concat)

    result = {
        "ground_truth": input_dict.get("citp_code"),
        "name": name,
        "classification": result.get("citp_code"),
        "confidence": result.get("confidence")
    }

    return result

# %% [markdown]
# ## Predictions

# %%
query_dict = products_df.to_dict("records")

# %%
query_dict
# Out:
# [{'label': 'accueillir les requérants et les faire enrôler  enrôler les requérants',
#   'citp_code': '422005'},
#  {'label': 'acheteur de cacao  cacao', 'citp_code': '611001'},
#  {'label': 'acheteur de cacao  peser, ramassager', 'citp_code': '611001'},
#  {'label': 'acheteur de produits agricoles (anacarde et mais)  acheter les produits agricoles (anacarde, mais) et revendre',
#   'citp_code': '332003'},
#  {'label': "acheteur d'hévéa  peser et acheter hevea", 'citp_code': '332003'},
#  {'label': 'agent commercial  promotion de produit (savon et chocolat et autre...)',
#   'citp_code': '333202'},
#  {'label': 'agent commercial  service les clients et faire la reception',
#   'citp_code': '333202'},
#  {'label': 'agent commerciale cie  accueillir les clients',
#   'citp_code': '333202'},
#  {'label': 'agent de mairie  ramaser les ordures', 'citp_code': '911002'},
#  {'label': "agent de securite  surveillance de l'universite de bouake",
#   'citp_code': '541401'},
#  {'label': 'agent de securite  vigiles', 'citp_code': '541401'},
#  {'label': 'agent de securite  surveillance de site de la dgi, surveillance de personnes et de biens',
#   'citp_code': '541401'},
#  {'label': 'agent de securite  agent de securite', 'citp_code': '541401'},
#  {'label': 'agent de sécurité  surveiller proteger les biens et service',
#   'citp_code': '541401'},
#  {'label': 'agent de sécurité  surveillance des biens et personnes',
#   'citp_code': '541401'},
#  {'label': 'agent de sécurité  surveiller les entrees et soties des personnes',
#   'citp_code': '541401'},
#  {'label': 'agent de securite pour une boulangerie  surveillance de l endroit',
#   'citp_code': '541401'},
#  {'label': 'agent immobilier  montrer les terrains et superviser les lotissements',
#   'citp_code': '333104'},
#  {'label': 'agent immobilier  prospection et recherche de biens immobiliers, conseils et accompagnement des clients, négociation et gestion des transactions...',
#   'citp_code': '333104'},
#  {'label': 'agentdu ministere des sports  infrastructure',
#   'citp_code': '342204'},
#  {'label': 'agriculeteur de mais, riz, arachide  cultiver le mais, riz, arachide',
#   'citp_code': '613001'},
#  {'label': "agriculteur  faire le netoyage planter et recolter quand c'est la saison",
#   'citp_code': '611001'},
#  {'label': 'agriculteur  cutliver et vente danacarde', 'citp_code': '611001'},
#  {'label': 'agriculteur  entretenir la plantation', 'citp_code': '611001'},
#  {'label': 'agriculteur  entretenir et planter du cacao',
#   'citp_code': '611001'},
#  {'label': 'agriculteur  culture et vente de produits vivriers',
#   'citp_code': '611001'},
#  {'label': 'agriculteur  agriculteur d anacardes', 'citp_code': '611001'},
#  {'label': 'agriculteur  ramasseur d anacardes et vente',
#   'citp_code': '611001'},
#  {'label': 'agriculteur  agriculteur d anacardes et revendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur  entretien et  supervision', 'citp_code': '611001'},
#  {'label': 'agriculteur  anacard  recolte  des noix  d anacard',
#   'citp_code': '611001'},
#  {'label': 'agriculteur  d igname  planter ,entretenir  et deterrer',
#   'citp_code': '613001'},
#  {'label': 'agriculteur  de cacao  entretenir, recolter et cabosser',
#   'citp_code': '611001'},
#  {'label': 'agriculteur  de cacao  aide dans le champs  de cacao',
#   'citp_code': '611001'},
#  {'label': 'agriculteur  de l’igname  faire les buttes d’igname, semer, entretenir la plantation et recolter l’igname',
#   'citp_code': '613001'},
#  {'label': 'agriculteur  de riz, maï, arachide et anacard  recolte  des noix de anacard',
#   'citp_code': '613001'},
#  {'label': "agriculteur anacarde et igname  culture d'anacarde",
#   'citp_code': '613001'},
#  {'label': 'agriculteur anacarde maïs riz arrachide manioc  cultiver anacarde maïs riz arrachide manioc',
#   'citp_code': '613001'},
#  {'label': 'agriculteur anacarde,maïs,riz et arrachide manioc  cultiver anacarde,maïs,riz arrachide et manioc',
#   'citp_code': '613001'},
#  {'label': 'agriculteur anarcade  cultive et vente de anacarde',
#   'citp_code': '611001'},
#  {'label': 'agriculteur cacao  cultiver cacao', 'citp_code': '611001'},
#  {'label': 'agriculteur cacao, banane et hevea  cultiver',
#   'citp_code': '611001'},
#  {'label': 'agriculteur cacao, cafe et cultures vivrieres  semer, recolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d anacarde  recolter de l anacarde',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d anacarde  je vais au champ nettoyer semer trier mes anacardes',
#   'citp_code': '611001'},
#  {'label': "agriculteur d 'anacarde  cultive et recolte",
#   'citp_code': '611001'},
#  {'label': "agriculteur d anacarde et de maïs  cultiuver le maïs et l'anacarde",
#   'citp_code': '611001'},
#  {'label': 'agriculteur d arnacarde  entretenir le champs',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d hevea  vendre la seve', 'citp_code': '611001'},
#  {'label': "agriculteur d 'igname  cultive et vend", 'citp_code': '613001'},
#  {'label': 'agriculteur d’anacade  entretien du champs par des journaiers',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacade  entretien du champs',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacade  entretien du champs',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacade  entretien du champs',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacade  entretien du champs',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacade  entretien du champs',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  semer,nettoyer, récolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  semer,nettoyer, récolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  semer, nettoyer, récolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  semer, nettoyer, récolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  semer, nettoyer, récolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  semer, nettoyer, récolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  semer, nettoyer, récolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  semer, nettoyer, récolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  je cultive', 'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  je cultive', 'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  semer, nettoyer, récolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  semer, nettoyer, récolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  semer, nettoyer, récolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  semer, nettoyer, récolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  semer, nettoyer, récolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  semer, nettoyer, récolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  semer,nettoyer, récolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  semer,nettoyer,récolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  semer, nettoyer, récolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  semer, nettoyer, récolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  ramassage d’anacarde',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  ramassage d’anacarde',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  semer,nettoyer, récolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  semer, nettoyer, récolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  semer ,nettoyer, récolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacarde  ramassage des grins d’anacarde',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacardes  nettoyer semer et recolter',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacardes  nettoyer semer et recolter',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacardes  nettoyer semer et recolter',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacardes  nettoyer semer et recolter',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacardes  nettoyer semer et recolter',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacardes  nettoyer semer et recolter',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacardes  nettoyer semer et recolter',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacardes  nettoyer semer et recolter',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacardes  nettoyer semer et recolter',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacardes  nettoyer semer et recolter',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anacardes  nettoyer semer et recolter',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’anarcade  cultiver et vendre de l’anacarde',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’arachide  semer, nettoyer, récolter et vendre',
#   'citp_code': '613001'},
#  {'label': 'agriculteur d’hévéa  entretenir la plantation récolter la production et faire le vente',
#   'citp_code': '611001'},
#  {'label': 'agriculteur d’igname  semer, nettoyer,récolter',
#   'citp_code': '613001'},
#  {'label': 'agriculteur d’igname  semer,nettoyer, récolter',
#   'citp_code': '613001'},
#  {'label': 'agriculteur d’ignames  nettoyer,  faire les buttes,  semer, recolter',
#   'citp_code': '613001'},
#  {'label': "agriculteur d'anacard  desherbage de la parcelle y planter les pepinieres et faire le suivi",
#   'citp_code': '611001'},
#  {'label': "agriculteur d'anacarde  cultiver et recolte",
#   'citp_code': '611001'},
#  {'label': "agriculteur d'anacarde  cultivateur", 'citp_code': '611001'},
#  {'label': "agriculteur d'anacarde  culture d'anacarde",
#   'citp_code': '611001'},
#  {'label': "agriculteur d'anacarde  nettoyer et cultiver",
#   'citp_code': '611001'},
#  {'label': "agriculteur d'anacarde,maïs,riz et manioc  cultiver l'anacarde,maïs,riz et manioc",
#   'citp_code': '613001'},
#  {'label': "agriculteur d'anacarde,maïs,riz et manioc  cultiver l'anacarde,maïs,riz et manioc",
#   'citp_code': '613001'},
#  {'label': "agriculteur d'arachide  cultive et recolter",
#   'citp_code': '613001'},
#  {'label': "agriculteur d'arachide  entretenir le champ",
#   'citp_code': '613001'},
#  {'label': "agriculteur d'arachide  deblayer le champs",
#   'citp_code': '613001'},
#  {'label': "agriculteur d'arachide  cultiver et recolter",
#   'citp_code': '613001'},
#  {'label': "agriculteur d'arachide  produire l'arachides",
#   'citp_code': '613001'},
#  {'label': "agriculteur d'arachides  recolter et vendre l'arachides",
#   'citp_code': '613001'},
#  {'label': "agriculteur d'arachides  recolter , transporter, et vendre l'aracchides",
#   'citp_code': '613001'},
#  {'label': "agriculteur d'arrachide  cultive et recolte",
#   'citp_code': '613001'},
#  {'label': "agriculteur d'arrachide  aller nettoyer planter et recolter",
#   'citp_code': '613001'},
#  {'label': 'agriculteur de anacard  aller au champ  pour recolter  les noix de anacard',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de anacard  aller  au champ pour recolter  des noix  de anacard',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de anacarde  semer, netoyage, ramassage',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de anacarde  semer, netoyage, ramassage, vente',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de anacarde  semer, nettoyage, ramassage',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de anacarde  semer, netoyage, ramassage',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de anacarde  vendre de an acarde',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de anacarde  vendre de anacarde',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de anacarde  vendre anacarde', 'citp_code': '611001'},
#  {'label': 'agriculteur de anacarde  vendre de anacarde',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de anacarde  vendre de anacarde',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de anacarde  semer, netoyer, ramasser',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de anacarde  semer, netoyer, ramasser',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de anacarde  agriculteur de anacarde',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de anarcade  nettoyer et entretenir',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de arachides  semer et entretenir le champ',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de bambou  planter, recolter et vendre',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de banane  entretien et suivi du champ',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de banane  entretien et suivi du champ',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de cacao  planter recolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  entretenir recolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  il cultive et il vend le cacao',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  deserber, bruler, planter, entretenir, recolter, cabosser, secher, vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  nettoyer la plantation',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  planter, débroussailler, récolter, sécher,  et vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  planter balayer et cabosser',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  planter balayer et cabosser',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  entretien', 'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  balayer entretenir le champ faire la cueillette ramasser cabosser et secher',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  balayer entretenir le champ faire la cueillette ramasser cabosser et secher',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  planter puis entretenir le champ de cacao',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  nettoyer, cabosser et sécher le cacao',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  balayer entretenir le champ faire la cueillette ramasser cabosser et secher',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  nettoyer entretenir le champ faire la cueillette ramasser cabosser et secher.',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  balayer entretenir le champ faire la cueillette ramasser cabosser et secher',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  entretenir et cultiver du cacao',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  entretenir le champ', 'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  produits et vendre le cacao',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  je cultive', 'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  je cultive', 'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  je cultive', 'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  balayer entretenir le champ faire la cueillette ramasser cabosser et secher',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  balayer entretenir le champ faire la cueillette ramasser cabosser et secher',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  culture de cacao', 'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  netoyer les mauvaises herbes, cueillir cacao',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  agriculture cacao', 'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  planter puis entretenir le champ de cacao',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  entretien et suivi du champ',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  entretien et suivi du champ',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  entretien et suivi du champ',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  cultive et vend le cacao',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  cultiver et vente de cacao',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  production et vente de cacao',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  entretient', 'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  nettoyer les mauvais herbes',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  nettoyer les mauvais herbes dans le champs',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  entretenir le champ de cacao fait la recolte et revendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  planter balayer et cabosser',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  planter balayer et cabosser',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  entretien et suivi du champ',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  entretien du champ', 'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  couper la foret, bruler, planter, entretenir, recolter, cabosser, secher, vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  cueillir les cabosses de cacao et extraire les fèves puis les secher pour ensuite les vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  cueillir les cabosses de cacao et extraire les fèves puis les secher pour ensuite les vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  cueillir, cabosser, secher, vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  cueillir les cabosses de cacao et extraire les fèves puis les secher pour ensuite les vendre',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  ramassage de feve de cacao',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  nettoyage du sol', 'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  vente de cacao', 'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  nettoyage du sol et planter',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  nettoyer la plantation de cacao',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao  entretenir le champ', 'citp_code': '611001'},
#  {'label': 'agriculteur de cacao cafe  cultive et vend le cacao cafe',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao et anacarde  entretenir le champ',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de cacao hévéa igname.  superviser les travaux des plantations la récolte de la production',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de céréales  semer, nettoyer et recolter les céréales',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de cereales, coton et riz  nettoyer, semer, recolter les produits agricoles',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de coton  cultiver et vendre du coton',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de coton  seme et recolter', 'citp_code': '613001'},
#  {'label': 'agriculteur de coton, anacarde et mais  nettoyer les champs, amenager la surface a cultiver, cultiver, pulveriser et recolter',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de culture vivrieres  planter desherber entretenir et recoter',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de gombo  semer, nettoyage, récolter',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de hevea  heveaculture', 'citp_code': '611001'},
#  {'label': 'agriculteur de igname  entretien et suivi du champ',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de igname  entretien et suivi du champ',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de igname et banane  entretien et suivi du champ',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de l anacarde  entretenir le champs',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de l igname  cultiver et vendre de l igname',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de l’anacarde  semer, recolter, secher et vendre l’anacarde',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de l’igname  faire les buttes d’igname, semer, recolter et vendre les igname',
#   'citp_code': '613001'},
#  {'label': "agriculteur de l'anacarde  cutliver nettoyer le champ",
#   'citp_code': '611001'},
#  {'label': "agriculteur de l'igname  netoyer et entretenir le champ",
#   'citp_code': '613001'},
#  {'label': 'agriculteur de maï ,riz, anacard  recolte  des amande  d’anacard',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de mais  semer, nettoyer, récolter',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de mais  nettoyer, desinfecter, entretenir, recolter et vendre',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de mais  entretenir le champs', 'citp_code': '613001'},
#  {'label': 'agriculteur de maïs  aller faire le nettoyage et attendre la recolte',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de maïs  saimer, nettoyer, recolter',
#   'citp_code': '613001'},
#  {'label': "agriculteur de maïs  aller au champ, faire le nettoyage, semer, recolter et vendre quand c'est beaucoup",
#   'citp_code': '613001'},
#  {'label': "agriculteur de maïs  aller au champ, faire le nettoyage, semer, recolter et vendre quand c'est beaucoup",
#   'citp_code': '613001'},
#  {'label': 'agriculteur de maïs  nettoyager semer recolter',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de maïs  cutiver le maïs', 'citp_code': '613001'},
#  {'label': 'agriculteur de maïs  cultiver le maïs', 'citp_code': '613001'},
#  {'label': 'agriculteur de mais et arachide  nettoyer, semer, desherber et recolter',
#   'citp_code': '613001'},
#  {'label': "agriculteur de mais et arachide  nettoyer, semer et recolter le mais, le riz et l'arachide",
#   'citp_code': '613001'},
#  {'label': "agriculteur de maïs et d'igname  cultivateur de maïs et d'igname",
#   'citp_code': '613001'},
#  {'label': 'agriculteur de mais et riz  nettoyer le champ, desherber, semer et recolter',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de mais, anacarde, coton et arachide  nettoyer, desherber, semer et cultiver',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de mais, arachide  nettoyer, desherber, semer et recolter',
#   'citp_code': '613001'},
#  {'label': "agriculteur de mais, arachide  recolter, transporter et vendre l'arachides",
#   'citp_code': '613001'},
#  {'label': 'agriculteur de mais, arachide  nettoyer, cultiver, recolter',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de mais, arachide et riz  nettoyer, desherber, semer et recolter',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de mais, arachide et riz  nettoyer, semer et recolter',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de mais, arachide, riz  nettoyer, desherber, semer et recolter',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de mais, arachides  produire du mais, arachides',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de mais, riz et arachide  nettoyer les champs, desherber, cultiver, recolter',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de maïs, riz et coton  cultiver le maïs, le riz et le coton',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de mais; riz et le mil  cultiver et entretenir',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de manioc  nettoyage, entretien et recolte',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de manioc  entretient et recolte',
#   'citp_code': '613001'},
#  {'label': "agriculteur de manioc et d'arachide  entretien et suivie de plantation",
#   'citp_code': '613001'},
#  {'label': "agriculteur de manioc et d'igname  cultiver , planter et recolter les production",
#   'citp_code': '613001'},
#  {'label': 'agriculteur de mil  nettoyer semer et recolter',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de mil  nettoyer semer et recolter',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de palmier a huile  recolter et nettoyer',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de palmier a huile  recolter et nettoyer',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de palmier à huile  planter, récolter et vendre les graine',
#   'citp_code': '611001'},
#  {'label': 'agriculteur de palmier à huile, cacao et hévéa  agriculteur de palmier à huile, cacao et hévéa',
#   'citp_code': '611001'},
#  {'label': "agriculteur de palmier et l'hévéa  planter, récolter et vendre",
#   'citp_code': '611001'},
#  {'label': 'agriculteur de piments et aubergines  semences et entretien du champs',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de piments et gombos  cultiver  entretenir le champ et récolter les produits',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de riz  agriculture', 'citp_code': '613001'},
#  {'label': 'agriculteur de riz  nettoyer le champ, desherber, semer et recolter',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de riz  cultive et recolte', 'citp_code': '613001'},
#  {'label': 'agriculteur de riz  semer le riz', 'citp_code': '613001'},
#  {'label': 'agriculteur de riz  nettoyer, cultiver et vendre',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de riz  agriculture', 'citp_code': '613001'},
#  {'label': 'agriculteur de riz  nettoyer,semer, récolter',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de riz  preparation du sol, selection des semences, entretien de la riziere, surveillance,  recolte',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de riz mais haricot  culture et vente de riz',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de riz,  nettoyer, cultiver et vendre',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de riz, mais  cultiver le mais',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de riz, mais, arachides  cultiver le mais',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de tomate  nettoyer semer entretenir et recolter',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de vivrier  cultiver du vivrier',
#   'citp_code': '613001'},
#  {'label': 'agriculteur de vivrier  cultiver', 'citp_code': '613001'},
#  {'label': 'agriculteur de vivriers  nettoyage, semer et recolte',
#   'citp_code': '613001'},
#  {'label': "agriculteur d'hévéa  planter et récolter hévéa",
#   'citp_code': '611001'},
#  {'label': "agriculteur d'igname  planter et recolter", 'citp_code': '613001'},
#  {'label': "agriculteur d'igname  desherbage de la parcelle faire les buttes et y mettre les tubercules",
#   'citp_code': '613001'},
#  {'label': "agriculteur d'igname  préparer la parcelle , faire les buttes,  faire le planting, entretenir, déterrer et faire la vente",
#   'citp_code': '613001'},
#  {'label': "agriculteur d'igname  cultiver l'igname", 'citp_code': '613001'},
#  {'label': "agriculteur d'igname  defricher la parcelle faire les butes planter les boutures",
#   'citp_code': '613001'},
#  {'label': "agriculteur d'igname  cultiver l'igname", 'citp_code': '613001'},
#  {'label': 'agriculteur du cacao  recolte du feve de cacao',
#   'citp_code': '611001'},
#  {'label': 'agriculteur du cacao  entretien et recolte vente du feve de cacao',
#   'citp_code': '611001'},
#  {'label': 'agriculteur du cacao  entretien du champs et recolte vente du feve de cacao',
#   'citp_code': '611001'},
#  {'label': 'agriculteur heveaculture  heveaculture', 'citp_code': '611001'},
#  {'label': 'agriculteur igname  nettoyer et mettre les boutures d’igname',
#   'citp_code': '613001'},
#  {'label': 'agriculteurs  entretenir la plantation', 'citp_code': '613001'},
#  {'label': 'agriculteurs  entretenir la plantation', 'citp_code': '613001'},
#  {'label': 'agriculteurs  igname', 'citp_code': '613001'},
#  {'label': 'agriculteurs  igname', 'citp_code': '613001'},
#  {'label': 'agriculteurs  igname', 'citp_code': '613001'},
#  {'label': 'agriculteurs  igname', 'citp_code': '613001'},
#  {'label': 'agriculteurs  igname', 'citp_code': '613001'},
#  {'label': 'agriculteurs  igname', 'citp_code': '613001'},
#  {'label': 'agriculteurs  igname', 'citp_code': '613001'},
#  {'label': 'agriculteurs  igname', 'citp_code': '613001'},
#  {'label': 'agriculteurs  igname et manioc', 'citp_code': '613001'},
#  {'label': 'agriculteurs  igname et manioc', 'citp_code': '613001'},
#  {'label': 'agriculteurs de igname  igname', 'citp_code': '613001'},
#  {'label': 'agriculteurs de manioc  ##n/a##', 'citp_code': '613001'},
#  {'label': 'agricultice de vivrier  cultiver le vivrier',
#   'citp_code': '613001'},
#  {'label': 'agricultrice  cultiver et vendre du vivrier',
#   'citp_code': '613001'},
#  {'label': 'agricultrice  nettoyer cultiver l arachiche et gombo',
#   'citp_code': '613001'},
#  {'label': 'agricultrice  entretien et recolter', 'citp_code': '613001'},
#  {'label': 'agricultrice  entretien et service repas', 'citp_code': '613001'},
#  {'label': 'agricultrice  entretien et service repas', 'citp_code': '613001'},
#  {'label': 'agricultrice  faire de l arachide', 'citp_code': '613001'},
#  {'label': 'agricultrice  agriculteur d anacardes et vente',
#   'citp_code': '611001'},
#  {'label': 'agricultrice  supervision', 'citp_code': '613001'},
#  {'label': 'agricultrice  d’arachides  je cultive', 'citp_code': '613001'},
#  {'label': 'agricultrice  de gombo  je cultive', 'citp_code': '613001'},
#  {'label': 'agricultrice cacao banane  cultiver', 'citp_code': '613001'},
#  {'label': 'agricultrice d hevea  vendre la seve', 'citp_code': '613001'},
#  {'label': 'agricultrice d igname  planter recolter et vendre',
#   'citp_code': '613001'},
#  {'label': 'agricultrice d’anacarde  ramassage d’anacarde',
#   'citp_code': '611001'},
#  {'label': 'agricultrice d’arachide  planter et recolter l’arachide',
#   'citp_code': '613001'},
#  {'label': 'agricultrice d’arachides  je cultive', 'citp_code': '613001'},
#  {'label': 'agricultrice d’igname et manioc  nettoyer la parcelle et y mettre les boutures d’igname et de manioc',
#   'citp_code': '613001'},
#  {'label': "agricultrice d'anacarde  culture d'anacarde",
#   'citp_code': '611001'},
#  {'label': "agricultrice d'arachide  entretien et service repas",
#   'citp_code': '613001'},
#  {'label': "agricultrice d'arachide  entretien et service repas",
#   'citp_code': '613001'},
#  {'label': "agricultrice d'arachide  entretien et nettoyage",
#   'citp_code': '613001'},
#  {'label': "agricultrice d'arachide  cultiver de l'arachide",
#   'citp_code': '613001'},
#  {'label': "agricultrice d'arachide  entretien et service repas",
#   'citp_code': '613001'},
#  {'label': "agricultrice d'arachide  desherber dans champ d'arachide",
#   'citp_code': '613001'},
#  {'label': 'agricultrice de  anacard  aller au champ  pour  recolter  les noix  de anacard',
#   'citp_code': '611001'},
#  {'label': 'agricultrice de anarcade  entretenir et recolter',
#   'citp_code': '611001'},
#  {'label': 'agricultrice de anarcade  entretenir et recolter',
#   'citp_code': '611001'},
#  {'label': 'agricultrice de anarcade  nettoyer et ramasser',
#   'citp_code': '611001'},
#  {'label': 'agricultrice de bambou  planter, recolter et vendre',
#   'citp_code': '613098'},
#  {'label': 'agricultrice de cacao  nettoyer les mauvais herbes',
#   'citp_code': '611001'},
#  {'label': 'agricultrice de cacao  planter puis entretenir le champ de cacao',
#   'citp_code': '611001'},
#  {'label': 'agricultrice de cacao  cueillir les cabosses de cacao et extraire les fèves puis les secher pour ensuite les vendre',
#   'citp_code': '611001'},
#  {'label': 'agricultrice de cacao  cueillir les cabosses de cacao et extraire les fèves puis les secher pour ensuite les vendre',
#   'citp_code': '611001'},
#  {'label': 'agricultrice de cacao banane manioc  je cultive',
#   'citp_code': '611001'},
#  {'label': 'agricultrice de cereales  semer ,nettoyer et recolter',
#   'citp_code': '613001'},
#  {'label': 'agricultrice de céréales  semer , nettoyer et récolter les céréales',
#   'citp_code': '613001'},
#  {'label': 'agricultrice de céréales  semer , nettoyer et récolter les céréales',
#   'citp_code': '613001'},
#  {'label': 'agricultrice de cultures maraîchères  planter, entretien, récolte et vente',
#   'citp_code': '613001'},
#  {'label': 'agricultrice de gombo  nettoyer semer entretenir et recolter',
#   'citp_code': '613001'},
#  {'label': 'agricultrice de gombo  je cultive', 'citp_code': '613001'},
#  {'label': 'agricultrice de gombo  nettoyer semer entretenir et recolter',
#   'citp_code': '613001'},
#  {'label': 'agricultrice de l’igname  semer et recolter l’igname',
#   'citp_code': '613001'},
#  {'label': 'agricultrice de légumes  semer du piment, de l’aubergine, recolter et vendre',
#   'citp_code': '613001'},
#  {'label': 'agricultrice de légumes  semer du piment et l’aubergine',
#   'citp_code': '613001'},
#  {'label': 'agricultrice de légumes  semer l’aubergine et le piment, recolter et vendre',
#   'citp_code': '613001'},
#  {'label': 'agricultrice de légumes  semer l’aubergine et le piment, entretenir, recolter',
#   'citp_code': '613001'},
#  {'label': 'agricultrice de légumes  semer le gombo et aubergine, recolter et vendre',
#   'citp_code': '613001'},
#  {'label': 'agricultrice de légumes  planter et vendre les légumes',
#   'citp_code': '613001'},
#  {'label': "agricultrice de maïs  aller au champ, faire le nettoyage, semer, recolter et vendre quand c'est beaucoup",
#   'citp_code': '613001'},
#  {'label': 'agricultrice de manioc  nettoyer planter entretenir et recolter',
#   'citp_code': '613001'},
#  {'label': 'agricultrice de manioc  recolter le manioc pour la vente',
#   'citp_code': '613001'},
#  {'label': 'agricultrice de manioc  semer les boutures de manioc',
#   'citp_code': '613001'},
#  {'label': 'agricultrice de manioc  planter et recolter le manioc',
#   'citp_code': '613001'},
#  {'label': 'agricultrice de riz  srmer le riz dans le bafond pour la production commerciale',
#   'citp_code': '613001'},
#  {'label': "agricultrice d'igname  cultiver l'igname", 'citp_code': '613001'},
#  {'label': "agricultrice d'igname  cultiver l'igname", 'citp_code': '613001'},
#  {'label': "agricultrice d'oignon  nettoyage et recolter quand c'est le moment",
#   'citp_code': '613001'},
#  {'label': 'agriculture  nettoyage et recolte', 'citp_code': '613001'},
#  {'label': 'agriculture anarcade  cultive et vente de anarcade',
#   'citp_code': '613001'},
#  {'label': 'agriculture d anacarde,cacao,banane plantin,manioc  recolter d anacarde et cacao',
#   'citp_code': '613001'},
#  {'label': 'agriculture d anacarde,cacao,banane plantin,manioc  recolte de cacao et anacarde',
#   'citp_code': '613001'},
#  {'label': "agriculture d'anacarde  aide au champ a nettoyer et faire les ceuillette",
#   'citp_code': '611001'},
#  {'label': "agriculture d'anacarde palmier igname et manioc  cultiver  nettoyer  entretenir les champs",
#   'citp_code': '611001'},
#  {'label': "agriculture d'anacarde,maïs,riz et manioc  cultiver l'anacarde,maïs,riz et manioc",
#   'citp_code': '613001'},
#  {'label': 'agriculture de anacarde  semer, netoyer, ramasser',
#   'citp_code': '611001'},
#  {'label': 'agriculture de banane manioc igname  cultiver les champs et recolter la production',
#   'citp_code': '613001'},
#  {'label': 'agriculture de cacao  plantation, recolte et entretien',
#   'citp_code': '611001'},
#  {'label': 'agriculture de cacao  il fait la culture de cacao et le  vend',
#   'citp_code': '611001'},
#  {'label': "agriculture de maïs  aller au champ, faire le nettoyage, semer, recolter et vendre quand c'est beaucoup",
#   'citp_code': '613001'},
#  {'label': "agriculture de maïs  aller au champ, faire le nettoyage, semer, recolter et vendre quand c'est beaucoup",
#   'citp_code': '613001'},
#  {'label': "agriculture de maïs  aller au champ, faire le nettoyage, semer, recolter et vendre quand c'est beaucoup",
#   'citp_code': '613001'},
#  {'label': 'agriculture de palmier et anacarde  faire les butes planter les grains nettoyer les champs  récolter la production',
#   'citp_code': '611001'},
#  {'label': 'agriculture de vivrier  agriculture de vivres',
#   'citp_code': '613001'},
#  {'label': "agriculture d'igname  cultiver l'igname", 'citp_code': '613001'},
#  {'label': "agriculture d'oignon  nettoyage, recolte, faire le tri, vente",
#   'citp_code': '613001'},
#  {'label': 'agriculture hevea  cultive et vente de hevea',
#   'citp_code': '611001'},
#  {'label': 'agriculture heveaculture  saigner hevea', 'citp_code': '611001'},
#  {'label': 'agriculture igname  cultiver planter entretenir',
#   'citp_code': '613001'},
#  {'label': 'agricultureur d anacarde et arrachide  cultiver l anacarde et l arrachide',
#   'citp_code': '611001'},
#  {'label': 'aide agricole  aide son conjoint dans les activites agricoles',
#   'citp_code': '611001'},
#  {'label': 'aide agriculteur  culture de riz mais arrachide anacardes...',
#   'citp_code': '613001'},
#  {'label': 'aide agriculteur de cacao  entretenir le champ',
#   'citp_code': '611001'},
#  {'label': 'aide agriculteur de cacao  nettoyer, recolter, cabosser, secher',
#   'citp_code': '611001'},
#  {'label': 'aide agriculteur de cacao  cabosser et secher le cacao',
#   'citp_code': '611001'},
#  {'label': 'aide agriculteur de cacao  entretenir le champ',
#   'citp_code': '611001'},
#  {'label': 'aide agricultrice  service repas', 'citp_code': '921001'},
#  {'label': 'aide agricultrice  aide agricultrice anacardes riz ...',
#   'citp_code': '613001'},
#  {'label': 'aide agricultrice de l’igname  recolter l’igname',
#   'citp_code': '613001'},
#  {'label': 'aide aux travaux champetres  semer,entretenir,recolter',
#   'citp_code': '921001'},
#  {'label': 'aide carreleur  aide carreleur', 'citp_code': '712002'},
#  {'label': 'aide cultivateur  cultiver', 'citp_code': '613001'},
#  {'label': "aide cultivateur anacarde  nettoyer le champ - recolter l'anacarde",
#   'citp_code': '611001'},
#  {'label': "aide cultivateur d'anacarde et coton  cultiver l'anacarde et le coton",
#   'citp_code': '611001'},
#  {'label': "aide cultivateur d'anacarde et de coton  cultiver l'anacarde et le coton",
#   'citp_code': '611001'},
#  {'label': "aide cultivateur d'anacarde et de coton  cultiver l'anacarde et le coton",
#   'citp_code': '611001'},
#  {'label': "aide cultivatrice anacarde et coton  cultiver l'anacarde etle coton",
#   'citp_code': '611001'},
#  {'label': "aide cultivatrice d'anacarde,de riz et de maïs  cultiver l'anacarde;le riz et maïs",
#   'citp_code': '611001'},
#  {'label': "aide cultivatrice d'anacarde;de coton et d'arachide  aide à cultiver l'anacarde, le coton et le riz",
#   'citp_code': '611001'},
#  {'label': "aide cultivatrice d'arachide  semer , récolter",
#   'citp_code': '921001'},
#  {'label': "aide cultivatrice de coton; riz et anacarde  aide à cultiver l'anacarde, de coton et de riz",
#   'citp_code': '611001'},
#  {'label': 'aide eleveur  elever bovins', 'citp_code': '612005'},
#  {'label': 'aide familial pour les travaux champetres  desherber,pulveriser,recolter et cabosser',
#   'citp_code': '921001'},
#  {'label': 'aide ferronier  soudure,  decoupe, montage',
#   'citp_code': '711006'},
#  {'label': 'aide infirmier  faire le traitement des malades',
#   'citp_code': '532004'},
#  {'label': 'aide macon  couper et ramasser les brique', 'citp_code': '931201'},
#  {'label': 'aide macon  melanger le sable avec du ciment et l eau ramassage de brique',
#   'citp_code': '931201'},
#  {'label': 'aide macon  melanger le ciment, ramasser le sable et les briques',
#   'citp_code': '931201'},
#  {'label': 'aide maçon  faire un soubatiment et dresser ,monter mur',
#   'citp_code': '931201'},
#  {'label': 'aide maçon  transporter et ranger les materiaux, apporter les materiaux',
#   'citp_code': '931201'},
#  {'label': 'aide maçon  aider le maçon dans la construction des bâtiments',
#   'citp_code': '931201'},
#  {'label': "aide maçon  aller sur les chantier voir s'il y a du travail proposer nos service et aider dans la fabrication des biques et la construction",
#   'citp_code': '931201'},
#  {'label': "aide maçon  aller sur les chantier voir s'il y a du travail proposer nos service et aider dans la fabrication des biques et la construction",
#   'citp_code': '931201'},
#  {'label': 'aide maçon  faire la fondation des maisons avant la construction',
#   'citp_code': '931201'},
#  {'label': 'aide maçon  aide le maçon dans ses taches', 'citp_code': '931201'},
#  {'label': 'aide soignante  faire les injections  , les pansements , les prélèvements',
#   'citp_code': '532004'},
#  {'label': 'aide soignante benevole  aide soignante', 'citp_code': '532004'},
#  {'label': 'aide transformateur de manioc  eplucher et laver le manioc',
#   'citp_code': '532004'},
#  {'label': 'aide vendeuse  de vetements  vente de vetements  en magasin',
#   'citp_code': '522001'},
#  {'label': 'aide vendeuse (legume + tubercule ...)  etaler la marchandise + vendre',
#   'citp_code': '962012'},
#  {'label': 'aide vendeuse (legume + tubercule ...)  etaler la marchandise + vendre',
#   'citp_code': '962012'},
#  {'label': 'aide vendeuse d’habits  vendre des habits', 'citp_code': '522001'},
#  {'label': "aide vendeuse de bijoux  vendre les chaînes, boucles d'oreilles aux clients",
#   'citp_code': '962012'},
#  {'label': 'aide vendeuse de légumes  vendre la tomate, aubergine, gombo et du piment',
#   'citp_code': '962012'},
#  {'label': 'aide vendeuse de poisson fume et vente  acheter-fumer-et vendre de poisson fume et frais',
#   'citp_code': '962012'},
#  {'label': 'aide vendeuse de restaurant  puiser, leau, faire la vaisselle, servir les clients',
#   'citp_code': '962012'},
#  {'label': 'aide vendeuse de restaurant  cuisiner,faire les plats,  servir les clients',
#   'citp_code': '941001'},
#  {'label': 'aide vendeuse de riz prepare  faire la cuisine, servir les clients',
#   'citp_code': '521106'},
#  {'label': 'aide-maçon  se rendre sur le chantier de construction pour travailler. souler les briques. decharger les camions',
#   'citp_code': '931201'},
#  {'label': 'apprenti coiffeuse  coiffer les clients', 'citp_code': '514001'},
#  {'label': "apprenti ferronnier  nettoyage de l'atelier, faire sortir les echantillons des articles realisés, aider le patron dans la realisation des nouveaux articles des clients, apresrealisation aller faire l'instalation",
#   'citp_code': '711006'},
#  {'label': 'apprenti macon  mouiller le ciment, transporter le materiel',
#   'citp_code': '931201'},
#  {'label': 'apprenti macon  mouiller, ramasser le sable et le ciment',
#   'citp_code': '931201'},
#  {'label': 'apprenti maçon  melange de sable, montage de mur, crépissage, mouiller béton',
#   'citp_code': '931201'},
#  {'label': 'apprenti mecanicien moto  reparer et entretenir les motos',
#   'citp_code': '723001'},
#  {'label': 'apprenti menuisier  fabrication de meubles',
#   'citp_code': '752001'},
#  {'label': 'apprenti-macon  melanger le ciment et sable',
#   'citp_code': '931201'},
#  {'label': 'apprentit macanique  reparation mecanique auto',
#   'citp_code': '723001'},
#  {'label': "artiste-chanteur  se rendre dans les bars, maquis et tout autre endroit pour chanter a n'importe quel moment",
#   'citp_code': '265202'},
#  {'label': 'auxilliaire infirmier consultant  recevoir les patients, enregistrer les patients',
#   'citp_code': '322002'},
#  {'label': 'ballayeur de champ  nettoyer et ramasser', 'citp_code': '611007'},
#  {'label': 'ballayeuse de rue  entretien des rues, ramassage des ordures',
#   'citp_code': '961005'},
#  {'label': 'berger  surveiller les moutons', 'citp_code': '516005'},
#  {'label': 'boulanger  faire entrer la farine dans le four',
#   'citp_code': '751202'},
#  {'label': 'boulangerie  je prepare du pain et je les vend',
#   'citp_code': '751202'},
#  {'label': 'boulangier traditionnel  fabriquer du pain',
#   'citp_code': '751202'},
#  {'label': 'boutiquier  vente de marchandises a prédominance alimentaire',
#   'citp_code': '521101'},
#  {'label': 'boutiquier  achat vente des articles faire le compte',
#   'citp_code': '521101'},
#  {'label': 'boutiquier  ouverture du magazin es matin receptionner les clients servir les clients',
#   'citp_code': '521101'},
#  {'label': 'boutiquier  réceptionner l’argent et servir les clients',
#   'citp_code': '521101'},
#  {'label': 'boutiquier  vendre des produits alimentaires ou non',
#   'citp_code': '521101'},
#  {'label': 'boutiquiere  aider a la vente et faire des achat',
#   'citp_code': '521101'},
#  {'label': 'boutiquiere  vendre des produits alimentaires',
#   'citp_code': '521101'},
#  {'label': 'bouvier  suivi des animaux', 'citp_code': '516005'},
#  {'label': "briquetier  aller sur le chantier, prendre le ciment le melanger avec le sable ajouter de l'eau et faire les biques",
#   'citp_code': '931201'},
#  {'label': 'caisiere  encaissement,faire les recus et les points des revenir',
#   'citp_code': '523001'},
#  {'label': 'caisiere dans magasin de vente de motos et pieces  encaiser,faire les recus et points',
#   'citp_code': '523001'},
#  {'label': 'caissière  enregistrer les entrées et sorties des dépenses au niveau de la coopérative',
#   'citp_code': '523001'},
#  {'label': 'carreauleur  revetir le sol et les murs de maisons',
#   'citp_code': '712002'},
#  {'label': 'carreleur  préparation du chantier,  mesures et decoupages ,pose des fondations et carrelage',
#   'citp_code': '712002'},
#  {'label': 'carreleur  placé les carreaux dans les maisons',
#   'citp_code': '712002'},
#  {'label': 'carreleur  placer les carreaux dans les logements',
#   'citp_code': '712002'},
#  {'label': 'carreleur  placer les carreaux', 'citp_code': '712002'},
#  {'label': 'carreleur  faire les carrelages', 'citp_code': '712002'},
#  {'label': 'carreleur  place les carreaux dans les batiments',
#   'citp_code': '712002'},
#  {'label': 'charbonnier  production et vente de charbon',
#   'citp_code': '962013'},
#  {'label': 'charpenterie,  meuble, plafonnerie  charpenterie,  meuble, plafonnerie',
#   'citp_code': '711004'},
#  {'label': 'charpentier  charpentier', 'citp_code': '711004'},
#  {'label': 'chaufeur de gros camion  transporter les produits viviers',
#   'citp_code': '833003'},
#  {'label': 'chauffeur  conduire le personnel', 'citp_code': '832203'},
#  {'label': 'chauffeur  conduire les passagers', 'citp_code': '832201'},
#  {'label': 'chauffeur  transporter le personnel administratif',
#   'citp_code': '832203'},
#  {'label': "chauffeur  je conduis le directeur de l'entreprise",
#   'citp_code': '832203'},
#  {'label': 'chauffeur  conduire des marchandises a des destination',
#   'citp_code': '832101'},
#  {'label': 'chauffeur  transport les marchandises', 'citp_code': '832101'},
#  {'label': 'chauffeur  recuperer le patron et le conduire pour ses differents deplacements',
#   'citp_code': '832203'},
#  {'label': 'chauffeur  de taxi  conduire  les passagers  a destination',
#   'citp_code': '832201'},
#  {'label': 'chauffeur  de taxi  conduire des clients a leur  destination',
#   'citp_code': '832201'},
#  {'label': 'chauffeur de  tricycle  chauffeur de taxi moto',
#   'citp_code': '832101'},
#  {'label': 'chauffeur de benne  transport de sable', 'citp_code': '833003'},
#  {'label': "chauffeur de camion kia  transport d'hévéa",
#   'citp_code': '833002'},
#  {'label': 'chauffeur de car  conduite de véhicules de transport',
#   'citp_code': '833002'},
#  {'label': 'chauffeur de car  chauffeur de car abidjan korhogo',
#   'citp_code': '833002'},
#  {'label': 'chauffeur de kia  transport de marchandises',
#   'citp_code': '832101'},
#  {'label': 'chauffeur de massa  conduit des passagers', 'citp_code': '833002'},
#  {'label': 'chauffeur de moto taxi  transporter les clients jusqu’à leur destination',
#   'citp_code': '832101'},
#  {'label': "chauffeur de moto taxi  effectuer des prestations de transport de personnes, conduire les clients jusqu'à a leurs destinations",
#   'citp_code': '832101'},
#  {'label': "chauffeur de moto taxi  effectuer des prestations de transport de personnes, conduire les clients jusqu'à a leurs destinations",
#   'citp_code': '832101'},
#  {'label': "chauffeur de moto taxi  effectuer des prestations de transport de personnes, conduire les clients jusqu'à a leurs destinations",
#   'citp_code': '832101'},
#  {'label': 'chauffeur de passagers et marchandises  transport de biens et de  personnes',
#   'citp_code': '832201'},
#  {'label': 'chauffeur de taxi  condu les personnes a destination',
#   'citp_code': '832201'},
#  {'label': 'chauffeur de taxi  conduire les usagers', 'citp_code': '832201'},
#  {'label': 'chauffeur de taxi  conduire les passagers', 'citp_code': '832201'},
#  {'label': 'chauffeur de taxi  conduire les passagers', 'citp_code': '832201'},
#  {'label': 'chauffeur de taxi  conduire des passagers dans la ville',
#   'citp_code': '832201'},
#  {'label': 'chauffeur de taxi communal  assurer le transport des passagers du village a la ville',
#   'citp_code': '832201'},
#  {'label': 'chauffeur de taxi communal  transporter les usagers dans leurs différents domiciles',
#   'citp_code': '832201'},
#  {'label': 'chauffeur de taxi moto  transport des biens et des personnes',
# ...
#  {'label': 'cultivatrice d’arachides  je cultive', 'citp_code': '613001'},
#  {'label': 'cultivatrice d’arachides  je cultive', 'citp_code': '613001'},
#  {'label': 'cultivatrice d’arrachide  production et vente d’arrachide',
#   'citp_code': '613001'},
#  {'label': 'cultivatrice d’igname  rassembler les ignames recoltees',
#   'citp_code': '613001'},
#  {'label': 'cultivatrice d’igname  désherbage, entretien',
#   'citp_code': '613001'},
#  {'label': 'cultivatrice d’igname  recolter des ignames',
#   'citp_code': '613001'},
#  {'label': 'cultivatrice d’igname  désherbage,  défrichage,  faire les buttes puis planter les tubercules,  entretien',
#   'citp_code': '613001'},
#  {'label': "cultivatrice d'arachide  deblayer le terrain pour la culture prochaine.",
#   'citp_code': '613001'},
#  {'label': "cultivatrice d'arachide  semer , récolter et vendre",
#   'citp_code': '613001'},
#  {'label': "cultivatrice d'arachide  cultiver et service repas",
#   'citp_code': '613001'},
#  {'label': "cultivatrice d'aubergine, gombo...  netoyer et arroser le jardin",
#   'citp_code': '613001'},
#  {'label': 'cultivatrice de banane  nettoyage, recolte',
#   'citp_code': '613001'},
#  {'label': 'cultivatrice de cacao  cultiver et vendre le cacao',
#   'citp_code': '611001'},
#  {'label': 'cultivatrice de cacao  ramassage', 'citp_code': '611001'},
#  {'label': 'cultivatrice de culture vivrières  désherbage,  labour, arrosage',
#   'citp_code': '613001'},
#  {'label': 'cultivatrice de l’arachide  je cultive', 'citp_code': '613001'},
#  {'label': 'cultivatrice de l’igname  cultiver de l’igname',
#   'citp_code': '613001'},
#  {'label': 'cultivatrice de l’igname  cultiver de l’igname',
#   'citp_code': '613001'},
#  {'label': 'cultivatrice de l’igname  cultiver de l’igname',
#   'citp_code': '613001'},
#  {'label': 'cultivatrice de legumes  entretenir, recolter les legumes',
#   'citp_code': '611006'},
#  {'label': 'cultivatrice de maïs  semer et récolter le maïs',
#   'citp_code': '611001'},
#  {'label': 'cultivatrice de maïs  semer et récolter le maïs',
#   'citp_code': '611001'},
#  {'label': 'cultivatrice de manioc  entretien mise de la sence en terre et recolte',
#   'citp_code': '611001'},
#  {'label': 'cultivatrice de manioc  préparation du terrain, sélection et préparation des boutures, planter les boutures, entretien de la culture, récolte',
#   'citp_code': '611001'},
#  {'label': 'cultivatrice de manioc  préparation du terrain, sélection et préparation des boutures, planter les boutures, entretien de la culture, récolte et commercialisation.',
#   'citp_code': '613001'},
#  {'label': 'cultivatrice de manioc  culture de manioc', 'citp_code': '613001'},
#  {'label': 'cultivatrice de manioc  culture de manioc', 'citp_code': '613001'},
#  {'label': 'cultivatrice de manioc  culture de manioc', 'citp_code': '613001'},
#  {'label': 'cultivatrice de manioc  préparation du terrain, sélection et préparation des boutures, planter les boutures, entretien de la culture, récolte et commercialisation.',
#   'citp_code': '613001'},
#  {'label': 'cultivatrice de riz  semer nettoyer recolter',
#   'citp_code': '611001'},
#  {'label': 'cultivatrice de tomate  cultiver, entretenir, recolter et vendre',
#   'citp_code': '611006'},
#  {'label': 'cultivatrice de tomate  cultiver, entretenir, recolter et vendre',
#   'citp_code': '611006'},
#  {'label': "cultivatrice d'igname  buttes nettoyage recolte vente",
#   'citp_code': '613001'},
#  {'label': "cultivatrice d'oignon  nettoyage, recolte, faire le tri, vente",
#   'citp_code': '611006'},
#  {'label': 'cultivatrice mais  nettoyer le champ - semer et recolter le mais',
#   'citp_code': '611001'},
#  {'label': 'cultivatrice mais  nettoyer le champ - recolter le mais - semer le mais',
#   'citp_code': '611001'},
#  {'label': 'culture  de manioc  culture et vente de manioc',
#   'citp_code': '613001'},
#  {'label': 'culture d’anacarde  recolter pour vendre', 'citp_code': '611001'},
#  {'label': 'culture d’anacarde  je cultive', 'citp_code': '611001'},
#  {'label': "culture d'anacarde,thèque,manioc et igname  cultiver l'anacarde, thèque,manioc et l' igname",
#   'citp_code': '611001'},
#  {'label': 'culture de cacao  planter,desherber,pulveriser, ceuillir,cabosser et vendre les feves de cacao',
#   'citp_code': '611001'},
#  {'label': 'culture de cacao  mettre les engrais et nettoyer le champ',
#   'citp_code': '611001'},
#  {'label': 'culture de gombo  culture gombo', 'citp_code': '611006'},
#  {'label': 'culture de gombo  cultiver du gombo', 'citp_code': '611006'},
#  {'label': 'culture de l anacarde,riz et maïs  cultiver anacarde,maïs et riz',
#   'citp_code': '611001'},
#  {'label': 'culture de legumes  semer,nettoyer,recolter et vendre la recolte obtenue',
#   'citp_code': '611006'},
#  {'label': "culture d'igname  buttes recolte vente", 'citp_code': '613001'},
#  {'label': 'culture du manioc  culture et vente de manioc',
#   'citp_code': '613001'},
#  {'label': 'culture maraîchères  culture et vente de legumes frais',
#   'citp_code': '611006'},
#  {'label': 'culture vivriere de tomate  cultivé et la vente des tomage',
#   'citp_code': '613001'},
#  {'label': 'culture vivrières  culture  marichaire', 'citp_code': '613001'},
#  {'label': 'cultuvateur de anacarde  balayer entrenir surveiller le champ recolter assecher et vendre',
#   'citp_code': '611001'},
#  {'label': 'cultuvateur de anacarde  nettoyer, semer  planter, entretenir ,recolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'cultuvateur de anacarde  balayer entrenir surveiller le champ recolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'cultuvateur de anacarde  balayer entrenir surveiller le champ faire’la recolte',
#   'citp_code': '611001'},
#  {'label': 'cultuvateur de anacarde  defrichez entrenir surveiller le champ recolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'cultuvateur de anacarde  nettoyer, planter, entretenir, recolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'cultuvateur de anacarde  balayer surveiller le champ recolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'cultuvateur de anacarde et autres culture maraîchers  nettoyer, planter, entretenir, recolter et vendre de l’anacarde',
#   'citp_code': '611001'},
#  {'label': 'cultuvateur de anacarde et autres culture vivrières  nettoyer, planter ou semer, recolter',
#   'citp_code': '611001'},
#  {'label': 'cultuvateur de anacarde et autres produits vivrières  nettoyer, planter, semer, recolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'cultuvateur de anacarde et riz  nettoyer, planter, ramasser, recolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'cultuvateur de anacarde, riz et maïs  nettoyer, semer ou planter, entretenir, recolter et vendre de anacarde,riz et maïs',
#   'citp_code': '611001'},
#  {'label': 'cultuvateur de anacarde,riz et maïs  nettoyer, semer, planter, recolter, ramasser et vendre de anacarde',
#   'citp_code': '611001'},
#  {'label': 'cultuvateur de cacao  culture et vente du cacao',
#   'citp_code': '611001'},
#  {'label': 'cultuvateur de cacao  cultuve le cacao', 'citp_code': '611001'},
#  {'label': 'cultuvateur de cacao  culture de cacao', 'citp_code': '611001'},
#  {'label': 'cultuvateur de cacao  cultuver entretenir recolter et vendre',
#   'citp_code': '611001'},
#  {'label': 'cultuvateur de cacao  culture et vente de cacao',
#   'citp_code': '611001'},
#  {'label': 'cultuvateur de igname  culture de igname', 'citp_code': '611001'},
#  {'label': 'cultuvateur de légumes et arachide  nettoyer, semer, planter, recolter et vendre',
#   'citp_code': '611006'},
#  {'label': 'cultuvateur de légumes et arachide  semer, planter, entretenir, recolter et vendre',
#   'citp_code': '611006'},
#  {'label': 'cultuvateur de manioc  defricher le champ entrenir surveiller le champ recolter vendre',
#   'citp_code': '613001'},
#  {'label': 'cultuvateur de riz et de soja  nettoyer, planter ou semer, entretenir, recolter et vendre de riz et soja',
#   'citp_code': '611001'},
#  {'label': 'cultuvateur maïs et autres produits vivrières  nettoyer, planter ou semer, entretenir, recolter ou ramasser et vendre de anacarde',
#   'citp_code': '613001'},
#  {'label': 'cultuvateur marechaire  culture de chou', 'citp_code': '611006'},
#  {'label': 'cultuvatrice de arachide  defricher le champ surveiller entrenir desherber recolter et vendre',
#   'citp_code': '613001'},
#  {'label': 'cultuvatrice de arachide et de manioc  nettoyer, planter, semer, recolter et vendre',
#   'citp_code': '613001'},
#  {'label': 'cultuvatrice de arachide, gombo haricots  nettoyer, semer, entretenir, recolter et vendre',
#   'citp_code': '613001'},
#  {'label': 'cultuvatrice de arachides  semer et entrenir le champ',
#   'citp_code': '613001'},
#  {'label': 'cultuvatrice de bannane  travaux champetres',
#   'citp_code': '613001'},
#  {'label': 'cultuvatrice de gombo et arachide  nettoyer, semer ou planter, entretenir, recolter et vendre',
#   'citp_code': '611006'},
#  {'label': 'cultuvatrice de gombo, arachide, haricots et ramassage de anacarde  nettoyer, semer ou planter, entretenir, recolter et vendre',
#   'citp_code': '611006'},
#  {'label': 'cultuvatrice de gombo, arachide, manioc  nettoyer la terre, planter,semer, recolter et vendre',
#   'citp_code': '611006'},
#  {'label': 'cultuvatrice de gombo,arachide, piment  nettoyer, semer ou planter, entretenir, recolter et vendre',
#   'citp_code': '611006'},
#  {'label': 'cultuvatrice de manioc  defricher le sol semer entrenir et surveiller le champ recolter',
#   'citp_code': '613001'},
#  {'label': 'cultuvatrice de manioc  semer entrenir et surveiller le champ recolter',
#   'citp_code': '613001'},
#  {'label': 'cultuvatrice de manioc  planter les tiges desherber le champ entre et surveiller le champ recolter et vendre',
#   'citp_code': '613001'},
#  {'label': 'cultuvatrice de manioc  defricher entrenir desherber surveiller le champ recolter et vendre',
#   'citp_code': '613001'},
#  {'label': 'cultuvatrice de manioc  culture de manioc', 'citp_code': '613001'},
#  {'label': 'cultuvatrice de manioc  desherber le champ planter les semences surveiller entrenir recolter et vendre',
#   'citp_code': '613001'},
#  {'label': 'cultuvatrice de manioc et autres produits vivrières  nettoyer, semer ou planter, entretenir, recolter et vendre',
#   'citp_code': '613001'},
#  {'label': 'cultuvatrice de manioc et les produits maraîchers  nettoyer, semer, recolter et vendre',
#   'citp_code': '613001'},
#  {'label': 'cultuvatrice de tomate  cultiver, entretenir recolter et vendre',
#   'citp_code': '611006'},
#  {'label': 'culvatrice de l’arachide  je cultive', 'citp_code': '613001'},
#  {'label': 'cutivateur de cacao  mettre les engrais et nettoyer',
#   'citp_code': '611001'},
#  {'label': 'dechargeur  decharger la marchandises des camions',
#   'citp_code': '933004'},
#  {'label': 'délégué médicale  faire la promotion de produits',
#   'citp_code': '325199'},
#  {'label': "directeur d'ecole primaire  donner des cours - gerer l'ecole",
#   'citp_code': '130099'},
#  {'label': 'docker  chargement et dechargement de camion',
#   'citp_code': '962004'},
#  {'label': 'docker  chargement et dechargement de mais et anacarde',
#   'citp_code': '962004'},
#  {'label': 'dockers  planifier et diriger l’équipe', 'citp_code': '962004'},
#  {'label': 'donner les cours a domicile  enseigner les eleves a domicile',
#   'citp_code': '531002'},
#  {'label': 'educateur  educateur dans un etablissement',
#   'citp_code': '235103'},
#  {'label': "educateur d'ecole  etablie les emploi du temps des eleves le suivie des eleves",
#   'citp_code': '235103'},
#  {'label': "educatrice  reception des parents d'eleves; contrôle des eleves et etudiants",
#   'citp_code': '235103'},
#  {'label': 'electricien  installation du courant', 'citp_code': '741001'},
#  {'label': 'electricien  electricite de batiment', 'citp_code': '741001'},
#  {'label': 'electricien auto  controler des pieces electriques et des systemes electronique du vehicule',
#   'citp_code': '723001'},
#  {'label': 'électricien auto  entretenir le système électrique des auto',
#   'citp_code': '723001'},
#  {'label': 'electricien plombier  réparation de fuite d’eau et de disfonctionnement électrique',
#   'citp_code': '741001'},
#  {'label': 'electricien-plombier  installation électronique et plomberie',
#   'citp_code': '741001'},
#  {'label': "elevage de poulet  pilier la bache, les nourrir et donner a boire et faire les vaccins quand c'est le moment",
#   'citp_code': '612002'},
#  {'label': 'eleveur  elever et vendre des bovins', 'citp_code': '612001'},
#  {'label': 'eleveur  elever des bovins', 'citp_code': '612001'},
#  {'label': 'eleveur  entretien du local nourrir les bêtes',
#   'citp_code': '612001'},
#  {'label': 'eleveur d’ovins  soigner et nourrir les animaux',
#   'citp_code': '612001'},
#  {'label': 'eleveur de bœuf  elevage et vente de  bœuf',
#   'citp_code': '612001'},
#  {'label': 'éleveur de bœuf  élever et vendre des bovins',
#   'citp_code': '612001'},
#  {'label': 'eleveur de boeufs  chaque jour je vais au champ avec les animaux les nourrit et autres soins',
#   'citp_code': '612001'},
#  {'label': 'eleveur de pondeuses  elevage et vente de pondeuse',
#   'citp_code': '612002'},
#  {'label': 'eleveur de porc  entretenir et nourrir', 'citp_code': '612001'},
#  {'label': 'eleveur de poussin  elever et vendre', 'citp_code': '612002'},
#  {'label': 'eleveur de volailles  nourrir les poulets et faire les ramassages des oeufs',
#   'citp_code': '612002'},
#  {'label': 'eleveur porc  donner a manger -  boire - vendre',
#   'citp_code': '612001'},
#  {'label': 'elle offre ses services  elle traisse les cheveux des femmes',
#   'citp_code': '514001'},
#  {'label': 'emploiyee de maison  faire le menage, preparer la nourriture et laver le linge',
#   'citp_code': '911001'},
#  {'label': 'encadreure pédagogique  apprenez aux enfants à lire et à écrire',
#   'citp_code': '531002'},
#  {'label': 'enseignant  enseigner les eleves', 'citp_code': '234001'},
#  {'label': 'enseignant  enseigner les personnes', 'citp_code': '234001'},
#  {'label': 'enseignant  enseigner les personnes', 'citp_code': '234001'},
#  {'label': 'enseignant au secondaire  dispenser les cours',
#   'citp_code': '233005'},
#  {'label': 'enseignant benevole  enseigner', 'citp_code': '234001'},
#  {'label': 'enseignant d ecole primaire  apprendre aux enfants a lire et ecrire',
#   'citp_code': '234001'},
#  {'label': 'enseignant de college  dispenser les cours',
#   'citp_code': '233005'},
#  {'label': 'enseignant de l ecole primaire  apprendre aux enfants a lire et ecrire',
#   'citp_code': '234001'},
#  {'label': "enseignant d'école primaire  donner des cours aux élèves du primaire",
#   'citp_code': '234001'},
#  {'label': "enseignant d'école primaire  donner des cours aux élèves du primaire",
#   'citp_code': '234001'},
#  {'label': "enseignant d'école primaire  enseigner les enfants",
#   'citp_code': '234001'},
#  {'label': 'enseignant du primaire  apprenez aux enfants a lire et ecrire en francais',
#   'citp_code': '234001'},
#  {'label': 'enseignant du primaire  enseignement', 'citp_code': '234001'},
#  {'label': 'enseignant du secondaire  apprendre aux eleves la langue allemande',
#   'citp_code': '233005'},
#  {'label': 'enseignant secondaire  enseigne les eleves',
#   'citp_code': '233005'},
#  {'label': 'enseignante  dispenser le savoir aux enfants',
#   'citp_code': '234001'},
#  {'label': 'enseignante  préparation des cours, expliquer clairement les concepts et assurer la progression des apprentissage, concevoir et corriger des évolutions...',
#   'citp_code': '234001'},
#  {'label': "enseignante à l'école primaire  apprendre aux enfants a lire et ecrire",
#   'citp_code': '234001'},
#  {'label': 'enseignante d ecole primaire  apprenez aux enfants a lire et à écrire',
#   'citp_code': '234001'},
#  {'label': 'enseignante d’école primaire au privé  apprenez aux enfants à lire et à écrire',
#   'citp_code': '234001'},
#  {'label': "enseignante d'école primaire  apprendre aux enfants a lire et ecrire",
#   'citp_code': '234001'},
#  {'label': 'enseignante franco-arabe  dispenser les savoir aux enfants',
#   'citp_code': '235299'},
#  {'label': 'enseignement  apprenez aux enfants a lire et a écrire',
#   'citp_code': '234001'},
#  {'label': 'enseignement bénévolat  dispensés les cours',
#   'citp_code': '234001'},
#  ...]

# %%
# %%time
results = [predict(item, client=client, encoder=encoder) for item in query_dict]
# Out:
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# ...
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(
# CPU times: total: 45min 7s
# Wall time: 31min 52s
# C:\Users\f.migone\AppData\Local\Temp\ipykernel_17152\478697674.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   hits = client.search(

# %%
results_df = pd.DataFrame(results)
results_df["correct"] = results_df["ground_truth"] == results_df["classification"]
results_df.to_csv(home.joinpath("results.csv"), index=False)

# %%
accuracy = results_df["correct"].sum() / len(results_df)

# %%
print("Accuracy: {:.2f}%\nExample DB: {}\nProducts classfied:{}".format(accuracy * 100, len(data_dict), len(query_dict)))
# Out:
# Accuracy: 50.27%
# Example DB: 5957
# Products classfied:3280
